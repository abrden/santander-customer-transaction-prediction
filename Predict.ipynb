# %%
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
# df = pd.read_csv('train.csv')
df = pd.read_feather('data_feather.fth')
# data = data.set_index('ID_code')
data = df.drop(columns=['ID_code'])
target = data['target']
data.drop(columns=['target'], inplace=True)
data.head()
# Out:
#      var_0   var_1    var_2   var_3    var_4   var_5   var_6    var_7   var_8  \
# 0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187  18.6266 -4.9200
# 1  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208  16.5338  3.1468
# 2   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427  14.6155 -4.9193
# 3  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428  14.9250 -5.8609
# 4   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405  19.2514  6.2654
#
#     var_9  ...  var_190_not_unique  var_191_not_unique  var_192_not_unique  \
# 0  5.7470  ...              4.4354              3.9642            3.136400
# 1  8.0851  ...              7.6421              7.7214            2.583700
# 2  5.9525  ...              2.9057              9.7905            1.670400
# 3  8.2450  ...              4.4666              4.7433            0.717800
# 4  7.6784  ...             -1.4905              9.5214            1.927839
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, train_size=0.66, test_size=0.33)

# %%
pipeline_optimizer = TPOTClassifier(generations=5, population_size=20, cv=5,random_state=42, verbosity=2)
pipeline_optimizer.fit(X_train, y_train)
print(pipeline_optimizer.score(X_test, y_test))
pipeline_optimizer.export('tpot_exported_pipeline_data_feather.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9144772723912353

# %%
cachedir = mkdtemp() # Create a temporary folder
memory = Memory(cachedir=cachedir, verbose=0)
                      
pipeline_optimizer = TPOTClassifier(generations=5, population_size=20, cv=5, random_state=42, memory=memory, verbosity=3)
pipeline_optimizer.fit(X_train, y_train)
print(pipeline_optimizer.score(X_test, y_test))
pipeline_optimizer.export('tpot_exported_pipeline_data_feather2.py')
